# %%
#PACKAGES & MODULES

# %%
#PyPi

#open source page that contains modules and packages
    #module: file of code defining functions, classes etc (A file containing a set of functions you want to include in your application), can be imported
    #package: collection of modules (containing an additional __init__.py file), directory
        #package needs file called __init__.py in a folder to be registered as package

#Installing external packages:
#through PC command line 
    #pip install package_name
    
#find packages on Google: "Python package for xyz"

#importing module from a package/subpackage:
    # from package import module (see link bookmarked)
    # from MainPackage.SubPackage import module (importing from sub-package)

#importing function from module:
    #from module import function
    #from package.module import function

#PURPOSE: STORE CODE IN ORGANIZED WAY

# %%
#name and __main__
