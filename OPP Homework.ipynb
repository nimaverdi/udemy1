# %%
#1) needs pythagorean theorem

class Line():
    
    def __init__(self,coor1,coor2):
        self.coor1=coor1
        self.coor2=coor2
    
    def distance(self):
        x=abs(self.coor1[0]-self.coor2[0]) #length of side x 
        y=abs(self.coor1[1]-self.coor2[1]) #length of side y
        length=sqrt(x**2 + y**2)
        return length
    
    def slope(self): #apply average rate of change
        pass
    
li = Line((1,1),(3,3))
li.distance()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-6bd6d54bda47> in <module>
#      17
#      18 li = Line((1,1),(3,3))
# ---> 19 li.distance()
#
# <ipython-input-11-6bd6d54bda47> in distance(self)
#      10         x=abs(self.coor1[0]-self.coor2[0]) #length of side x
#      11         y=abs(self.coor1[1]-self.coor2[1]) #length of side y
# ---> 12         length=sqrt(x**2 + y**2)
#      13         return length
#      14
#
# NameError: name 'sqrt' is not defined
